# %% [markdown]
# # 05 — Additional final figures
# Optional appendix / backup figures for the report and slides.

# %%
from pathlib import Path
import pandas as pd
from src.export_final_assets import main as export_main

cwd = Path.cwd().resolve()
root = cwd.parent if cwd.name == "notebooks" else cwd
print("Project root:", root)
export_main()
print("Done")
