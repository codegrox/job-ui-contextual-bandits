# %% [markdown]
# # Generator diagnostics
# Load summary and diagnostic CSVs and inspect marginals.

# %%
from pathlib import Path
import pandas as pd
root = Path('..').resolve()
summ = root / 'data' / 'summaries'
for p in sorted(summ.glob('*.csv')):
    print('---', p.name)
    print(pd.read_csv(p).head())
# Out:
# --- diagnostic_arm_by_context.csv
#         session_goal oracle_arm_name  count  share_within_goal
# 0  broad_exploration       card_grid     63           0.000753
# 1  broad_exploration     guided_chat  37417           0.447256
# 2  broad_exploration   hybrid_ranked  46161           0.551776
# 3  broad_exploration      swipe_fast     18           0.000215
# 4      casual_browse     guided_chat  43339           0.731633
# --- diagnostic_fit_vs_interview.csv
#        fit_decile  interview_rate  mean_reward
# 0  (0.363, 0.621]        0.087033     0.086699
# 1  (0.621, 0.678]        0.111367     0.110995
# 2  (0.678, 0.716]        0.126533     0.123854
# 3  (0.716, 0.743]        0.132967     0.130017
# 4  (0.743, 0.766]        0.140367     0.139718
# --- diagnostic_oracle_gap.csv
#    round_id  instant_expected_regret  oracle_expected_reward  \
# 0         0                 0.030347                0.168045
# 1         1                 0.000000                0.145000
# ...
